# %%
import numpy as np
import pandas as pd
from sklearn import linear_model as lm
from sklearn import metrics as mt

# %%
X_training = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Regression\X_training.csv")
y_training = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Regression\y_training.csv")

X_validation = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Regression\X_validation.csv")
y_validation = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Regression\y_validation.csv")

X_test = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Regression\X_test.csv")
y_test = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Regression\y_test.csv")

# %%
resultados = []

for n in range (1,10):
    for i in [0.5, 0.6, 0.7, 0.8, 0.9, 1]:
        elastic = lm.ElasticNet(alpha=n, l1_ratio=i ,max_iter=10000)
        elastic.fit(X_training, y_training)
        y_pred = elastic.predict(X_training)

        
        # Calcula a acurácia (ou outra métrica que desejar)
        R2 = mt.r2_score(y_training, y_pred)
        MSE = mt.mean_squared_error(y_training, y_pred)
        RMSE = mt.root_mean_squared_error(y_training, y_pred)
        MAE = mt.mean_absolute_error(y_training, y_pred)        
        MAPE = mt.mean_absolute_percentage_error(y_training, y_pred)

        resultados.append({
            'alpha': n,
            'ratio': i,
            'R2': R2,
            'MSE': MSE,
            'RMSE': RMSE,
            'MAE': MAE,
            'MAPE': MAPE
        })
# Exibe os resultados em um DataFrame
pd.DataFrame(resultados)
# Out:
#     alpha  ratio        R2         MSE       RMSE        MAE      MAPE
# 0       1    0.5  0.007832  474.268889  21.777715  17.299507  8.732300
# 1       1    0.6  0.007579  474.389767  21.780491  17.302422  8.734125
# 2       1    0.7  0.007388  474.480839  21.782581  17.304805  8.735937
# 3       1    0.8  0.007309  474.518703  21.783450  17.305913  8.736789
# 4       1    0.9  0.007351  474.498646  21.782990  17.305716  8.736747
# 5       1    1.0  0.007401  474.474834  21.782443  17.305484  8.736697
# 6       2    0.5  0.004368  475.924363  21.815691  17.326820  8.739289
# 7       2    0.6  0.004047  476.077957  21.819211  17.329673  8.739531
# 8       2    0.7  0.003632  476.276517  21.823760  17.333371  8.739836
# 9       2    0.8  0.003075  476.542530  21.829854  17.338363  8.740233
# 10      2    0.9  0.002294  476.915979  21.838406  17.345274  8.740767
# 11      2    1.0  0.001125  477.474834  21.851198  17.355395  8.741522
# 12      3    0.5  0.002114  477.002155  21.840379  17.346839  8.740886
# 13      3    0.6  0.001291  477.395653  21.849386  17.353980  8.741418
# 14      3    0.7  0.000141  477.945109  21.861956  17.363748  8.742126
# 15      3    0.8  0.000000  478.012560  21.863498  17.365090  8.742213
# 16      3    0.9  0.000000  478.012560  21.863498  17.365090  8.742213
# 17      3    1.0  0.000000  478.012560  21.863498  17.365090  8.742213
# 18      4    0.5  0.000383  477.829551  21.859313  17.361632  8.741978
# 19      4    0.6  0.000000  478.012560  21.863498  17.365090  8.742213
# 20      4    0.7  0.000000  478.012560  21.863498  17.365090  8.742213
# 21      4    0.8  0.000000  478.012560  21.863498  17.365090  8.742213
# 22      4    0.9  0.000000  478.012560  21.863498  17.365090  8.742213
# 23      4    1.0  0.000000  478.012560  21.863498  17.365090  8.742213
# 24      5    0.5  0.000000  478.012560  21.863498  17.365090  8.742213
# 25      5    0.6  0.000000  478.012560  21.863498  17.365090  8.742213
# 26      5    0.7  0.000000  478.012560  21.863498  17.365090  8.742213
# 27      5    0.8  0.000000  478.012560  21.863498  17.365090  8.742213
# 28      5    0.9  0.000000  478.012560  21.863498  17.365090  8.742213
# 29      5    1.0  0.000000  478.012560  21.863498  17.365090  8.742213
# 30      6    0.5  0.000000  478.012560  21.863498  17.365090  8.742213
# 31      6    0.6  0.000000  478.012560  21.863498  17.365090  8.742213
# 32      6    0.7  0.000000  478.012560  21.863498  17.365090  8.742213
# 33      6    0.8  0.000000  478.012560  21.863498  17.365090  8.742213
# 34      6    0.9  0.000000  478.012560  21.863498  17.365090  8.742213
# 35      6    1.0  0.000000  478.012560  21.863498  17.365090  8.742213
# 36      7    0.5  0.000000  478.012560  21.863498  17.365090  8.742213
# 37      7    0.6  0.000000  478.012560  21.863498  17.365090  8.742213
# 38      7    0.7  0.000000  478.012560  21.863498  17.365090  8.742213
# 39      7    0.8  0.000000  478.012560  21.863498  17.365090  8.742213
# 40      7    0.9  0.000000  478.012560  21.863498  17.365090  8.742213
# 41      7    1.0  0.000000  478.012560  21.863498  17.365090  8.742213
# 42      8    0.5  0.000000  478.012560  21.863498  17.365090  8.742213
# 43      8    0.6  0.000000  478.012560  21.863498  17.365090  8.742213
# 44      8    0.7  0.000000  478.012560  21.863498  17.365090  8.742213
# 45      8    0.8  0.000000  478.012560  21.863498  17.365090  8.742213
# 46      8    0.9  0.000000  478.012560  21.863498  17.365090  8.742213
# 47      8    1.0  0.000000  478.012560  21.863498  17.365090  8.742213
# 48      9    0.5  0.000000  478.012560  21.863498  17.365090  8.742213
# 49      9    0.6  0.000000  478.012560  21.863498  17.365090  8.742213
# 50      9    0.7  0.000000  478.012560  21.863498  17.365090  8.742213
# 51      9    0.8  0.000000  478.012560  21.863498  17.365090  8.742213
# 52      9    0.9  0.000000  478.012560  21.863498  17.365090  8.742213
# 53      9    1.0  0.000000  478.012560  21.863498  17.365090  8.742213

# %%
#Validation
resultados = []

elastic = lm.ElasticNet(alpha=1, l1_ratio=0.5 ,max_iter=10000)
elastic.fit(X_training, y_training)
y_pred = elastic.predict(X_validation)

# Calcula a acurácia (ou outra métrica que desejar)
R2 = mt.r2_score(y_validation, y_pred)
MSE = mt.mean_squared_error(y_validation, y_pred)
RMSE = mt.root_mean_squared_error(y_validation, y_pred)
MAE = mt.mean_absolute_error(y_validation, y_pred)        
MAPE = mt.mean_absolute_percentage_error(y_validation, y_pred)
resultados.append({
    'alpha': "1",
    'R2': R2,
    'MSE': MSE,
    'RMSE': RMSE,
    'MAE': MAE,
    'MAPE': MAPE
})
# Exibe os resultados em um DataFrame
pd.DataFrame(resultados)
# Out:
#   alpha        R2         MSE       RMSE        MAE      MAPE
# 0     1  0.008117  473.635616  21.763171  17.262903  8.694035

# %%
elastic = lm.ElasticNet(alpha=1, l1_ratio=0.5 ,max_iter=10000)
elastic.fit(pd.concat([X_training, X_validation]), pd.concat([y_training, y_validation]))
y_pred_test = elastic.predict(X_test)


resultados = []

# Calcula a acurácia (ou outra métrica que desejar)
R2 = mt.r2_score(y_test, y_pred_test)
MSE = mt.mean_squared_error(y_test, y_pred_test)
RMSE = mt.root_mean_squared_error(y_test, y_pred_test)
MAE = mt.mean_absolute_error(y_test, y_pred_test)        
MAPE = mt.mean_absolute_percentage_error(y_test, y_pred_test)

resultados.append({
    'R2': R2,
    'MSE': MSE,
    'RMSE': RMSE,
    'MAE': MAE,
    'MAPE': MAPE
})
# Exibe os resultados em um DataFrame
pd.DataFrame(resultados)
# Out:
#          R2         MSE       RMSE       MAE      MAPE
# 0  0.007897  483.055928  21.978533  17.47163  8.746263
