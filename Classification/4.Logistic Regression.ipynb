# %%
import numpy as np
import pandas as pd
from sklearn import metrics as mt 
from sklearn import linear_model as lm

# %%
X_training = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Classification\X_training.csv")
y_training = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Classification\y_training.csv").values.ravel()

X_validation = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Classification\X_validation.csv")
y_validation = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Classification\y_validation.csv").values.ravel()

X_test = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Classification\X_test.csv")
y_test = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Classification\y_test.csv").values.ravel()

# %%
# Hyperparameter search
resultados = []
for C in [0.01, 0.1, 1, 10]:
    for solver in ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']:
        for max_iter in [100, 200, 500]:
            model = lm.LogisticRegression(C=C, solver=solver, max_iter=max_iter, random_state=0)
            model.fit(X_training, y_training)
            y_pred = model.predict(X_training)
            # Calcula a acurácia (ou outra métrica que desejar)
            acuracia = mt.accuracy_score(y_training, y_pred)
            precisao = mt.precision_score(y_training, y_pred)
            recall = mt.recall_score(y_training, y_pred)
            f1_score = mt.f1_score (y_training, y_pred)
        
            resultados.append({
                'C': C,
                'solver': solver,
                'max_iter': max_iter,
                'acuracia': acuracia,
                'precisao': precisao,
                'recall': recall,
                'F1_score': f1_score
            })
# Exibe os resultados em um DataFrame
pd.DataFrame(resultados)
# Out:
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\scipy\optimize\_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\utils\optimize.py:100: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\scipy\optimize\_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\utils\optimize.py:100: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\scipy\optimize\_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\utils\optimize.py:100: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\scipy\optimize\_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\utils\optimize.py:100: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\scipy\optimize\_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\utils\optimize.py:100: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\scipy\optimize\_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\utils\optimize.py:100: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\scipy\optimize\_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\utils\optimize.py:100: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\scipy\optimize\_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\utils\optimize.py:100: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\scipy\optimize\_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\utils\optimize.py:100: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\scipy\optimize\_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\utils\optimize.py:100: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\scipy\optimize\_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\utils\optimize.py:100: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\scipy\optimize\_linesearch.py:312: LineSearchWarning: The line search algorithm did not converge
#   alpha_star, phi_star, old_fval, derphi_star = scalar_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\utils\optimize.py:100: LineSearchWarning: The line search algorithm did not converge
#   ret = line_search_wolfe2(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\ProgramData\anaconda3\envs\bacon\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
#         C     solver  max_iter  acuracia  precisao    recall  F1_score
# 0    0.01      lbfgs       100  0.861587  0.834412  0.849147  0.841715
# 1    0.01      lbfgs       200  0.874288  0.869257  0.835624  0.852109
# 2    0.01      lbfgs       500  0.873378  0.871882  0.829770  0.850305
# 3    0.01  liblinear       100  0.793850  0.729340  0.833747  0.778057
# 4    0.01  liblinear       200  0.793850  0.729340  0.833747  0.778057
# ..    ...        ...       ...       ...       ...       ...       ...
# 67  10.00        sag       200  0.567372  0.622807  0.004518  0.008971
# 68  10.00        sag       500  0.567731  0.575368  0.009959  0.019580
# 69  10.00       saga       100  0.566724  0.588235  0.000955  0.001906
# 70  10.00       saga       200  0.566669  0.524272  0.001718  0.003425
# 71  10.00       saga       500  0.568034  0.674497  0.006396  0.012671
#
# [72 rows x 7 columns]

# %%
resultados = []

model = lm.LogisticRegression(C=0.1, solver='newton-cholesky', max_iter=100, random_state=0)
model.fit(X_training, y_training)
y_pred = model.predict(X_validation)
# Calcula a acurácia (ou outra métrica que desejar)
acuracia = mt.accuracy_score(y_validation, y_pred)
precisao = mt.precision_score(y_validation, y_pred)
recall = mt.recall_score(y_validation, y_pred)
f1_score = mt.f1_score (y_validation, y_pred)
        
resultados.append({
    'C': "0.1",
    'solver': "newton_cholesky",
    'max_iter': "100",
    'acuracia': acuracia,
    'precisao': precisao,
    'recall': recall,
    'F1_score': f1_score
})
# Exibe os resultados em um DataFrame
pd.DataFrame(resultados)
# Out:
#      C           solver max_iter  acuracia  precisao    recall  F1_score
# 0  0.1  newton_cholesky      100  0.874127  0.868854  0.835697  0.851953

# %%
resultados = []
# Retrain on train+val and evaluate on test set
model_final = lm.LogisticRegression(C=0.1, solver='newton-cholesky', max_iter=100, random_state=0)
model_final.fit(pd.concat([X_training, X_validation]), np.concatenate([y_training, y_validation]))
y_pred_test = model_final.predict(X_test)
# Calcula a acurácia (ou outra métrica que desejar)
acuracia = mt.accuracy_score(y_test, y_pred_test)
precisao = mt.precision_score(y_test, y_pred_test)
recall = mt.recall_score(y_test, y_pred_test)
f1_score = mt.f1_score (y_test, y_pred_test)
        
resultados.append({
    'C': "0.1",
    'solver': "newton_cholesky",
    'max_iter': "100",
    'acuracia': acuracia,
    'precisao': precisao,
    'recall': recall,
    'F1_score': f1_score
})
# Exibe os resultados em um DataFrame
pd.DataFrame(resultados)
# Out:
#      C           solver max_iter  acuracia  precisao    recall  F1_score
# 0  0.1  newton_cholesky      100  0.871317  0.867307  0.834492  0.850583
