# %%
import pandas as pd
import numpy as np
from sklearn     import tree     as tr
from sklearn import metrics as mt

# %%
X_training = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Classification\X_training.csv")
y_training = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Classification\y_training.csv").values.ravel()

X_validation = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Classification\X_validation.csv")
y_validation = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Classification\y_validation.csv").values.ravel()

X_test = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Classification\X_test.csv")
y_test = pd.read_csv (r"C:\Users\muzio\OneDrive\Documentos\repos\machine_learning\Classification\y_test.csv").values.ravel()

# %%
# Search for best max_depth
resultados = []
for depth in range(1, 50):
    clf = tr.DecisionTreeClassifier(max_depth=depth, random_state=0)
    clf.fit(X_training, y_training)
    y_pred = clf.predict(X_training)
    
    # Calcula a acurácia (ou outra métrica que desejar)
    acuracia = mt.accuracy_score(y_training, y_pred)
    precisao = mt.precision_score(y_training, y_pred)
    recall = mt.recall_score(y_training, y_pred)
    f1_score = mt.f1_score (y_training, y_pred)
    
    resultados.append({
        'max_depth': depth,
        'acuracia': acuracia,
        'precisao': precisao,
        'recall': recall,
        'F1_score': f1_score
    })

# Exibe os resultados em um DataFrame
pd.DataFrame(resultados)
# Out:
#     max_depth  acuracia  precisao    recall  F1_score
# 0           1  0.788251  0.723603  0.827511  0.772076
# 1           2  0.857092  0.829749  0.843293  0.836466
# 2           3  0.884162  0.839506  0.905912  0.871446
# 3           4  0.893443  0.923308  0.822451  0.869966
# 4           5  0.906764  0.907732  0.873680  0.890381
# 5           6  0.922816  0.901864  0.922267  0.911951
# 6           7  0.934483  0.952659  0.893216  0.921980
# 7           8  0.942702  0.950332  0.915648  0.932668
# 8           9  0.949528  0.961784  0.920103  0.940482
# 9          10  0.955471  0.963601  0.932481  0.947785
# 10         11  0.961056  0.969318  0.939894  0.954380
# 11         12  0.966421  0.976843  0.944922  0.960617
# 12         13  0.970847  0.977645  0.954563  0.965966
# 13         14  0.974529  0.981885  0.958922  0.970268
# 14         15  0.977922  0.985766  0.962963  0.974231
# 15         16  0.981080  0.986753  0.969359  0.977978
# 16         17  0.984610  0.990612  0.973718  0.982092
# 17         18  0.987341  0.991589  0.979095  0.985303
# 18         19  0.989712  0.992994  0.983200  0.988073
# 19         20  0.991809  0.994198  0.986859  0.990515
# 20         21  0.993574  0.996154  0.988991  0.992559
# 21         22  0.995132  0.996231  0.992523  0.994374
# 22         23  0.996373  0.997129  0.994495  0.995810
# 23         24  0.997490  0.997675  0.996532  0.997103
# 24         25  0.998359  0.998028  0.998186  0.998107
# 25         26  0.998966  0.999140  0.998473  0.998806
# 26         27  0.999352  0.999777  0.998727  0.999252
# 27         28  0.999559  0.999745  0.999236  0.999491
# 28         29  0.999793  0.999873  0.999650  0.999761
# 29         30  0.999890  0.999873  0.999873  0.999873
# 30         31  0.999972  0.999968  0.999968  0.999968
# 31         32  1.000000  1.000000  1.000000  1.000000
# 32         33  1.000000  1.000000  1.000000  1.000000
# 33         34  1.000000  1.000000  1.000000  1.000000
# 34         35  1.000000  1.000000  1.000000  1.000000
# 35         36  1.000000  1.000000  1.000000  1.000000
# 36         37  1.000000  1.000000  1.000000  1.000000
# 37         38  1.000000  1.000000  1.000000  1.000000
# 38         39  1.000000  1.000000  1.000000  1.000000
# 39         40  1.000000  1.000000  1.000000  1.000000
# 40         41  1.000000  1.000000  1.000000  1.000000
# 41         42  1.000000  1.000000  1.000000  1.000000
# 42         43  1.000000  1.000000  1.000000  1.000000
# 43         44  1.000000  1.000000  1.000000  1.000000
# 44         45  1.000000  1.000000  1.000000  1.000000
# 45         46  1.000000  1.000000  1.000000  1.000000
# 46         47  1.000000  1.000000  1.000000  1.000000
# 47         48  1.000000  1.000000  1.000000  1.000000
# 48         49  1.000000  1.000000  1.000000  1.000000

# %%
resultados = []

clf = tr.DecisionTreeClassifier(max_depth=32, random_state=0)
clf.fit(X_training, y_training)
y_pred = clf.predict(X_validation)
   
# Calcula a acurácia (ou outra métrica que desejar)
acuracia = mt.accuracy_score(y_validation, y_pred)
precisao = mt.precision_score(y_validation, y_pred)
recall = mt.recall_score(y_validation, y_pred)
f1_score = mt.f1_score (y_validation, y_pred)
    
resultados.append({
    'max_depth': depth,
    'acuracia': acuracia,
    'precisao': precisao,
    'recall': recall,
    'F1_score': f1_score
     })

# Exibe os resultados em um DataFrame
pd.DataFrame(resultados)
# Out:
#    max_depth  acuracia  precisao    recall  F1_score
# 0         49  0.945944   0.93621  0.939268  0.937736

# %%
resultados = []
# Retrain on train+val and evaluate on test set
clf_final = tr.DecisionTreeClassifier(max_depth=32, random_state=0)
clf_final.fit(pd.concat([X_training, X_validation]), np.concatenate([y_training, y_validation]))
y_pred_test = clf_final.predict(X_test)

# Calcula a acurácia (ou outra métrica que desejar)
acuracia = mt.accuracy_score(y_test, y_pred_test)
precisao = mt.precision_score(y_test, y_pred_test)
recall = mt.recall_score(y_test, y_pred_test)
f1_score = mt.f1_score (y_test, y_pred_test)
    
resultados.append({
    'acuracia': acuracia,
    'precisao': precisao,
    'recall': recall,
    'F1_score': f1_score
     })

# Exibe os resultados em um DataFrame
pd.DataFrame(resultados)
# Out:
#    acuracia  precisao    recall  F1_score
# 0  0.946935  0.937779  0.941575  0.939673
